# %%
import numpy as np
import os
import glob
import pandas as pd
from statsmodels.sandbox.stats.multicomp import multipletests
import numpy as np
from subprocess import call

# %%
dir_pre = "/mnt/hpc/home/xuxinran/DirectSeq/data/zhaolin_240206/240201-zhaolin-RNA-merge/v0.7.2/isoform/nano_merge"

output_path = f"{dir_pre}_signal_irqtl.csv"

# %%
files = glob.glob(f'{dir_pre}_haplotype_chr*_tmp.csv')
dfs = [pd.read_csv(file) for file in files]
df = pd.concat(dfs, ignore_index=True)
df = df.sort_values(by=['chrom', 'snp_pos_1base'])
df = df.reset_index(drop=True)

# %%
df
# Out:
#       chrom strand  snp_pos_1base         rsID A1 A2  \
# 0      chr1      -         935671  rs116904365  C  G
# 1      chr1      -         935833    rs3128115  G  C
# 2      chr1      +         949608       rs1921  A  G
# 3      chr1      +         949831  rs116002608  T  C
# 4      chr1      +         949889    rs3829742  A  G
# ...     ...    ...            ...          ... .. ..
# 10251  chr9      +      140167022    rs3204123  G  A
# 10252  chr9      +      140167877       rs8281  T  G
# 10253  chr9      +      140167985   rs28740782  T  A
# 10254  chr9      +      140446707  rs149264137  A  G
# 10255  chr9      +      140446955    rs2298170  T  G
#
#                                             isoform_id_l       MAF  \
# 0      1ceb1440-2056-4ce7-9971-7a98eb265c65-0_chr1:93...  0.073530
# 1      1ceb1440-2056-4ce7-9971-7a98eb265c65-0_chr1:93...  0.115000
# 2        ENST00000649529.1_5_ENSG00000187608.10_13,other  0.237400
# 3        ENST00000649529.1_5_ENSG00000187608.10_13,other  0.038460
# 4        ENST00000649529.1_5_ENSG00000187608.10_13,other  0.038460
# ...                                                  ...       ...
# 10251  ENST00000343053.6_9_ENSG00000188986.9_10,e738d...  0.476000
# 10252  ENST00000343053.6_9_ENSG00000188986.9_10,e738d...  0.456700
# 10253  ENST00000343053.6_9_ENSG00000188986.9_10,e738d...  0.476000
# 10254  ENST00000371443.6_4_ENSG00000182154.8_7,e638cb...  0.009709
# 10255      ENST00000371443.6_4_ENSG00000182154.8_7,other  0.014420
#
#        A1_isoform1  A2_isoform1  A1_isoform2  A2_isoform2   p_value      beta
# 0             10.0          0.0         17.0          2.0  0.532020  0.797803
# 1              5.0          3.0          5.0          4.0  1.000000  0.287682
# 2           6116.0      14212.0          1.0          6.0  0.682421  0.948581
# 3            854.0      19566.0          0.0          9.0  1.000000 -0.565829
# 4            906.0      19212.0          0.0          9.0  1.000000 -0.488513
# ...            ...          ...          ...          ...       ...       ...
# 10251         43.0         55.0          1.0          0.0  0.444444 -1.089684
# 10252         41.0         54.0          1.0          0.0  0.437500 -1.118376
# 10253         40.0         52.0          1.0          0.0  0.440860 -1.105406
# 10254         49.0       2204.0          0.0          2.0  1.000000 -2.492076
# 10255         24.0       1658.0          0.0          2.0  1.000000 -2.905711
#
# [10256 rows x 14 columns]

# %%
p_adjusted = multipletests(df["p_value"], method='fdr_bh')
df['fdr'] = p_adjusted[1]
print("pvalue小于0.05的个数：", len(df[df['p_value']<0.05]))
print("pvalue小于0.01的个数：", len(df[df['p_value']<0.01]))
print("fdr小于0.1的个数：", len(df[df['fdr']<0.1]))
# Out:
# pvalue小于0.05的个数： 416
# pvalue小于0.01的个数： 146
# fdr小于0.1的个数： 65

# %%
result_df = df[df['p_value']<0.05]
result_df.to_csv(output_path, index=False)
call(f'rm {dir_pre}_haplotype_chr*_tmp.csv',shell=True)
# Out:
# 0
